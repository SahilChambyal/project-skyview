# %%
import kagglehub
import pandas
import numpy
import os

# %%
path = kagglehub.dataset_download('erkappo/cvusa-dataset')

for _dir, _, _files in os.walk(path):
    print(_dir)
# Out:
# /kaggle/input/cvusa-dataset
# /kaggle/input/cvusa-dataset/Dataset_CVUSA
# /kaggle/input/cvusa-dataset/Dataset_CVUSA/polarmap
# /kaggle/input/cvusa-dataset/Dataset_CVUSA/polarmap/segmap
# /kaggle/input/cvusa-dataset/Dataset_CVUSA/polarmap/normal
# /kaggle/input/cvusa-dataset/Dataset_CVUSA/segmap
# /kaggle/input/cvusa-dataset/Dataset_CVUSA/bingmap
# /kaggle/input/cvusa-dataset/Dataset_CVUSA/streetview
